# %%
import pandas as pd 
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sn
from datetime import date

# %%
df = pd.read_csv("./sample2.csv")

# %%
# Out:
# True

# %%
from datetime import datetime

df["date_mutation"] = [datetime.strptime(i, '%Y-%m-%d') for i in df["date_mutation"]]

# %%
#df["Valeur fonciere"] = [float(str(i).split(",")[0]) for i in df["Valeur fonciere"]]

# %%
datetime.min.time()
# Out:
# datetime.time(0, 0)

# %%
datetime.combine(date(2021,1,1),datetime.min.time())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/alz02/Documents/M1_EFREI/visualisation/Project/prj.ipynb Cellule 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/alz02/Documents/M1_EFREI/visualisation/Project/prj.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> datetime.combine(date(2021,1,1))
#
# TypeError: combine() missing required argument 'time' (pos 2)

# %%
keys = {
    "nature_mutation": list(df["nature_mutation"].value_counts().index),
    "valeur_fonciere": [df["valeur_fonciere"].min(), df["valeur_fonciere"].max()],
    "nom_commune": list(df["nom_commune"].value_counts().index),
    "nombre_lots": [df["nombre_lots"].min(),df["nombre_lots"].max()],
    "type_local": list(df["type_local"].value_counts().index),
    "surface_reelle_bati": [df["surface_reelle_bati"].min(), df["surface_reelle_bati"].max()],
    "nombre_pieces_principales": [df["nombre_pieces_principales"].min,df["nombre_pieces_principales"].max()],
    "surface_terrain": [df["surface_terrain"].min(), df["surface_terrain"].max()]
}

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id_mutation', 'date_mutation', 'numero_disposition',
#        'nature_mutation', 'valeur_fonciere', 'adresse_numero',
#        'adresse_suffixe', 'adresse_nom_voie', 'adresse_code_voie',
#        'code_postal', 'code_commune', 'nom_commune', 'code_departement',
#        'ancien_code_commune', 'ancien_nom_commune', 'id_parcelle',
#        'ancien_id_parcelle', 'numero_volume', 'lot1_numero',
#        'lot1_surface_carrez', 'lot2_numero', 'lot2_surface_carrez',
#        'lot3_numero', 'lot3_surface_carrez', 'lot4_numero',
#        'lot4_surface_carrez', 'lot5_numero', 'lot5_surface_carrez',
#        'nombre_lots', 'code_type_local', 'type_local', 'surface_reelle_bati',
#        'nombre_pieces_principales', 'code_nature_culture', 'nature_culture',
#        'code_nature_culture_speciale', 'nature_culture_speciale',
#        'surface_terrain', 'longitude', 'latitude'],
#       dtype='object')

# %%
df = df[~df[["latitude","longitude"]][:1500].isna()]

# %%
df[(df["latitude"]!=pd.NA) & (df["longitude"]!=pd.NA)]
# Out:
#       Unnamed: 0 id_mutation date_mutation  numero_disposition  \
# 0            NaN         NaN           NaN                 NaN
# 1            NaN         NaN           NaN                 NaN
# 2            NaN         NaN           NaN                 NaN
# 3            NaN         NaN           NaN                 NaN
# 4            NaN         NaN           NaN                 NaN
# ...          ...         ...           ...                 ...
# 9995         NaN         NaN           NaN                 NaN
# 9996         NaN         NaN           NaN                 NaN
# 9997         NaN         NaN           NaN                 NaN
# 9998         NaN         NaN           NaN                 NaN
# 9999         NaN         NaN           NaN                 NaN
#
#      nature_mutation  valeur_fonciere  adresse_numero adresse_suffixe  \
# 0                NaN              NaN             NaN             NaN
# ...

# %%
df["surface_reelle_bati"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 9995   NaN
# 9996   NaN
# 9997   NaN
# 9998   NaN
# 9999   NaN
# Name: surface_reelle_bati, Length: 10000, dtype: float64

# %%
df[df["date_mutation"].between(df["date_mutation"][0],df["date_mutation"][5])]
# Out:
#       Unnamed: 0 id_mutation date_mutation  numero_disposition  \
# 0              0      2017-1    2017-01-02                   1
# 1              1      2017-2    2017-01-05                   1
# 2              2      2017-3    2017-01-06                   1
# 3              3      2017-3    2017-01-06                   1
# 4              4      2017-3    2017-01-06                   1
# ...          ...         ...           ...                 ...
# 9986        9986   2017-3982    2017-01-06                   1
# 9987        9987   2017-3982    2017-01-06                   1
# 9988        9988   2017-3982    2017-01-06                   1
# 9989        9989   2017-3982    2017-01-06                   1
# 9990        9990   2017-3982    2017-01-06                   1
#
#      nature_mutation  valeur_fonciere  adresse_numero adresse_suffixe  \
# 0              Vente          27000.0            83.0             NaN
# ...
